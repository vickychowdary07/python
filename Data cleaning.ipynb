# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/census-number-of-people-riding-public-transportation-1.csv')
df
# Out:
#                   Year (date)                                     Tract Name  \
# 0      01/01/2019 12:00:00 AM     Census Tract 416, Clark County, Washington
# 1      01/01/2019 12:00:00 AM     Census Tract 430, Clark County, Washington
# 2      01/01/2019 12:00:00 AM  Census Tract 408.05, Clark County, Washington
# 3      01/01/2019 12:00:00 AM  Census Tract 404.03, Clark County, Washington
# 4      01/01/2019 12:00:00 AM  Census Tract 406.04, Clark County, Washington
# ...                       ...                                            ...
# 14575  01/01/2013 12:00:00 AM      Census Tract 328, King County, Washington
# 14576  01/01/2013 12:00:00 AM        Census Tract 1, King County, Washington
# 14577  01/01/2013 12:00:00 AM        Census Tract 8, King County, Washington
# 14578  01/01/2013 12:00:00 AM       Census Tract 10, King County, Washington
# 14579  01/01/2013 12:00:00 AM       Census Tract 12, King County, Washington
#
# ...

# %%
df.head(5)
# Out:
#               Year (date)                                     Tract Name  \
# 0  01/01/2019 12:00:00 AM     Census Tract 416, Clark County, Washington
# 1  01/01/2019 12:00:00 AM     Census Tract 430, Clark County, Washington
# 2  01/01/2019 12:00:00 AM  Census Tract 408.05, Clark County, Washington
# 3  01/01/2019 12:00:00 AM  Census Tract 404.03, Clark County, Washington
# 4  01/01/2019 12:00:00 AM  Census Tract 406.04, Clark County, Washington
#
#    B01003_001E  B08006_008E  State  County  Tract ID  Year (text)
# 0         3486           41     53      11     41600         2019
# 1         1993            0     53      11     43000         2019
# 2         6981          120     53      11     40805         2019
# 3         4204            0     53      11     40403         2019
# 4         5810           24     53      11     40604         2019

# %%
df.tail(5)
# Out:
#                   Year (date)                                 Tract Name  \
# 14575  01/01/2013 12:00:00 AM  Census Tract 328, King County, Washington
# 14576  01/01/2013 12:00:00 AM    Census Tract 1, King County, Washington
# 14577  01/01/2013 12:00:00 AM    Census Tract 8, King County, Washington
# 14578  01/01/2013 12:00:00 AM   Census Tract 10, King County, Washington
# 14579  01/01/2013 12:00:00 AM   Census Tract 12, King County, Washington
#
#        B01003_001E  B08006_008E  State  County  Tract ID  Year (text)
# 14575         2531           39     53      33     32800         2013
# 14576         6282          755     53      33       100         2013
# 14577         2691          197     53      33       800         2013
# 14578         1891          181     53      33      1000         2013
# 14579         6226          792     53      33      1200         2013

# %% [markdown]
# #DATA Cleaning

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/census-number-of-people-riding-public-transportation-1.csv')

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14575    False
# 14576    False
# 14577    False
# 14578    False
# 14579    False
# Length: 14580, dtype: bool

# %%
df.isnull().sum()
# Out:
# Year (date)    0
# Tract Name     0
# B01003_001E    0
# B08006_008E    0
# State          0
# County         0
# Tract ID       0
# Year (text)    0
# dtype: int64

# %%
mv=["N/a","na",np.nan]
df=pd.read_csv('//content//wfs.csv',na_values=mv)
# Out:
# <ipython-input-8-77ed68512265>:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('//content//wfs.csv',na_values=mv)

# %%
df.isnull().sum()
# Out:
# type                                 0
# id                                   0
# geometry_type                        0
# geometry_coordinates                 0
# geometry_name                        0
# properties_status                    0
# properties_remarks                7913
# properties_source                43161
# properties_iso3                     22
# properties_country                   0
# properties_lastcheckdate        117632
# properties_createdate                1
# properties_updatedate                1
# properties_gdb_geomattr_data    117642
# dtype: int64

# %%
df.drop(["properties_lastcheckdate","properties_gdb_geomattr_data"],axis=1,inplace=True)

# %%
dfc=df.dropna(axis=0,subset=["properties_remarks","properties_source","properties_iso3","properties_createdate","properties_updatedate"])

# %%
dfc.isnull().sum()
# Out:
# type                     0
# id                       0
# geometry_type            0
# geometry_coordinates     0
# geometry_name            0
# properties_status        0
# properties_remarks       0
# properties_source        0
# properties_iso3          0
# properties_country       0
# properties_createdate    0
# properties_updatedate    0
# dtype: int64
